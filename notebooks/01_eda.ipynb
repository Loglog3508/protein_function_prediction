# %% [markdown]
# # Protein Function Prediction: EDA
#
# This notebook calls the versioned EDA module so report tables and figures remain reproducible.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))
from src.eda import run_eda

summary = run_eda(PROJECT_ROOT)
summary
